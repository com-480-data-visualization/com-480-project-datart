# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('salary3.csv')

# %%
df
# Out:
#                    region  year      election    Votants    Inscrits  \
# 0    Auvergne-Rhône-Alpes  2002   legislative  2796920.0   4493882.5
# 1    Auvergne-Rhône-Alpes  2002  presidential  3609544.0   4650467.0
# 2    Auvergne-Rhône-Alpes  2004    cantonales  1444151.0   2242130.0
# 3    Auvergne-Rhône-Alpes  2007   legislative  2634939.5   4422235.5
# 4    Auvergne-Rhône-Alpes  2007  presidential  5259116.0   6124008.5
# ..                    ...   ...           ...        ...         ...
# 154         Île-de-France  2007  presidential  9001644.5  10531676.0
# 155         Île-de-France  2008    cantonales  1274183.0   2429458.5
# 156         Île-de-France  2011    cantonales  1086443.5   2811160.0
# 157         Île-de-France  2012   legislative  3818206.0   6915841.5
# 158         Île-de-France  2012  presidential  5531531.0   6943717.0
#
#      social-contribution  gross-salary     Total  Metric
# 0                 1611.0       16411.0   7115944  Salary
# ...

# %%
df['participation'] = (df['Votants']/df['Inscrits'])*100

# %%
df['absent'] = 100 - df['participation']

# %%
df
# Out:
#                    region  year      election    Votants    Inscrits  \
# 0    Auvergne-Rhône-Alpes  2002   legislative  2796920.0   4493882.5
# 1    Auvergne-Rhône-Alpes  2002  presidential  3609544.0   4650467.0
# 2    Auvergne-Rhône-Alpes  2004    cantonales  1444151.0   2242130.0
# 3    Auvergne-Rhône-Alpes  2007   legislative  2634939.5   4422235.5
# 4    Auvergne-Rhône-Alpes  2007  presidential  5259116.0   6124008.5
# ..                    ...   ...           ...        ...         ...
# 154         Île-de-France  2007  presidential  9001644.5  10531676.0
# 155         Île-de-France  2008    cantonales  1274183.0   2429458.5
# 156         Île-de-France  2011    cantonales  1086443.5   2811160.0
# 157         Île-de-France  2012   legislative  3818206.0   6915841.5
# 158         Île-de-France  2012  presidential  5531531.0   6943717.0
#
#      social-contribution  gross-salary     Total  Metric  participation  \
# ...

# %%
df.to_csv('salary_final.csv', index=False)
