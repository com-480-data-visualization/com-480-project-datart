# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('salary-contribution.csv')

# %%
df
# Out:
#                    region  year      election       Votants  \
# 0    Auvergne-Rhône-Alpes  2002   legislative  5.706206e+05
# 1    Auvergne-Rhône-Alpes  2002  presidential  7.022932e+05
# 2    Auvergne-Rhône-Alpes  2004    cantonales  7.241479e+04
# 3    Auvergne-Rhône-Alpes  2007   legislative  5.802836e+05
# 4    Auvergne-Rhône-Alpes  2007  presidential  1.051058e+06
# ..                    ...   ...           ...           ...
# 154         Île-de-France  2007  presidential  7.752880e+05
# 155         Île-de-France  2008    cantonales  7.131016e+04
# 156         Île-de-France  2011    cantonales  4.997099e+04
# 157         Île-de-France  2012   legislative  3.164254e+05
# 158         Île-de-France  2012  presidential  4.568450e+05
#
#      socialcontribution  grosssalary     Total  Metric
# 0                1611.0      16411.0   7115944  Salary
# 1                1611.0      16411.0   7115944  Salary
# 2                1734.0      17344.0   7231833  Salary
# ...

# %%
df['participation'] = (df['Votants']/df['Total'])*100

# %%
df.to_csv('salary2.csv', index=False)
