# %%
import pandas as pd
import numpy as np

# %%
uk_region_age=pd.read_excel('uk_data/uk_region_age.xlsx')
uk_region_age.head(20)
# Out:
#         Unnamed: 0 Unnamed: 1         Unnamed: 2         Unnamed: 3  \
# 0              NaN        NaN                NaN                NaN
# 1              NaN        NaN                NaN                NaN
# 2              NaN        NaN                NaN                NaN
# 3              NaN        NaN                NaN                NaN
# 4   Mid-year 2001   All ages                 NaN                NaN
# 5              NaN  All ages       Aged 0 to 15                 NaN
# 6              NaN        NaN      Aged 0 to 15        Aged 0 to 4
# 7              NaN        NaN                NaN      Aged 5 to 15
# 8              NaN        NaN     Aged 16 to 64                 NaN
# 9              NaN        NaN     Aged 16 to 64      Aged 16 to 24
# 10             NaN        NaN                NaN     Aged 25 to 44
# 11             NaN        NaN                NaN     Aged 45 to 64
# 12             NaN        NaN  Aged 65 and over                 NaN
# ...

# %%
age_range=list(uk_region_age['Unnamed: 3'][[6,7,9,10,11,13,14,15]])
age_range
# Out:
# ['Aged 0 to 4 ',
#  'Aged 5 to 15 ',
#  'Aged 16 to 24 ',
#  'Aged 25 to 44 ',
#  'Aged 45 to 64 ',
#  'Aged 65 to 74 ',
#  'Aged 75 to 84 ',
#  'Aged 85 and over ']

# %%
region_list=list(uk_region_age.iloc[2][4:13])
region_list=region_list+['England']
region_list
# Out:
# ['North East ',
#  'North West ',
#  'Yorkshire and the Humber ',
#  'East Midlands ',
#  'West Midlands ',
#  'East ',
#  'London ',
#  'South East ',
#  'South West ',
#  'England']

# %%
index_1=[]
for year in range(2010,2019):
    index_1=index_1+[year]*10

index_2=region_list*9

# %%
age_row
# Out:
# [6, 7, 9, 10, 11, 13, 14, 15]

# %%
range(4,14)[0]
# Out:
# 4

# %%
new_df=pd.DataFrame(np.zeros((90,8)), index=[index_1,index_2],columns=age_range)
age_row=np.array([6,7,9,10,11,13,14,15])+12*9
region_col=range(4,14)
for i in range(10):
    for j in range(8):
        new_df.iloc[i,j]=uk_region_age.iloc[age_row[j],region_col[i]]

# %%
age_row+12
# Out:
# array([126, 127, 129, 130, 131, 133, 134, 135])

# %%
uk_region_age['Unnamed: 3']
# Out:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#              ...
# 215       Aged 45 to 64
# 216                  NaN
# 217       Aged 65 to 74
# 218       Aged 75 to 84
# 219    Aged 85 and over
# Name: Unnamed: 3, Length: 220, dtype: object

# %%
age_row
# Out:
# [6, 7, 9, 10, 11, 13, 14, 15]

# %%
age_row=age_row+12
region_col=range(4,14)
for i in range(10):
    for j in range(8):
        new_df.iloc[i+10,j]=uk_region_age.iloc[age_row[j],region_col[i]]

# %%
age_row=age_row+12
region_col=range(4,14)
for i in range(10):
    for j in range(8):
        new_df.iloc[i+20,j]=uk_region_age.iloc[age_row[j],region_col[i]]

# %%
age_row=age_row+12
region_col=range(4,14)
for i in range(10):
    for j in range(8):
        new_df.iloc[i+30,j]=uk_region_age.iloc[age_row[j],region_col[i]]

# %%
age_row=age_row+12
region_col=range(4,14)
for i in range(10):
    for j in range(8):
        new_df.iloc[i+40,j]=uk_region_age.iloc[age_row[j],region_col[i]]

# %%
age_row=age_row+12
region_col=range(4,14)
for i in range(10):
    for j in range(8):
        new_df.iloc[i+50,j]=uk_region_age.iloc[age_row[j],region_col[i]]

# %%
age_row=age_row+12
region_col=range(4,14)
for i in range(10):
    for j in range(8):
        new_df.iloc[i+60,j]=uk_region_age.iloc[age_row[j],region_col[i]]

# %%
age_row=age_row+12
region_col=range(4,14)
for i in range(10):
    for j in range(8):
        new_df.iloc[i+70,j]=uk_region_age.iloc[age_row[j],region_col[i]]

# %%
age_row=age_row+12
region_col=range(4,14)
for i in range(10):
    for j in range(8):
        new_df.iloc[i+80,j]=uk_region_age.iloc[age_row[j],region_col[i]]

# %%
new_df
# Out:
#                                 Aged 0 to 4   Aged 5 to 15   Aged 16 to 24   \
# 2010 North East                     148513.0       313212.0        320432.0
#      North West                     429023.0       891638.0        855968.0
#      Yorkshire and the Humber       325361.0       666608.0        660172.0
#      East Midlands                  267593.0       567675.0        540454.0
#      West Midlands                  351449.0       737376.0        671308.0
# ...                                      ...            ...             ...
# 2018 East                           372157.0       828826.0        606654.0
#      London                         615881.0      1218914.0        933076.0
#      South East                     527245.0      1228022.0        950440.0
#      South West                     296357.0       690551.0        585372.0
#      England                       3346727.0      7401731.0       6005483.0
#
# ...

# %%
male_region_age=pd.read_excel('uk_data/uk_region_age_male.xlsx')
male_region_age.head(20)
# Out:
#         Unnamed: 0 Unnamed: 1         Unnamed: 2         Unnamed: 3  \
# 0              NaN        NaN                NaN                NaN
# 1              NaN        NaN                NaN                NaN
# 2              NaN        NaN                NaN                NaN
# 3              NaN        NaN                NaN                NaN
# 4   Mid-year 2001   All ages                 NaN                NaN
# 5              NaN  All ages       Aged 0 to 15                 NaN
# 6              NaN        NaN      Aged 0 to 15        Aged 0 to 4
# 7              NaN        NaN                NaN      Aged 5 to 15
# 8              NaN        NaN     Aged 16 to 64                 NaN
# 9              NaN        NaN     Aged 16 to 64      Aged 16 to 24
# 10             NaN        NaN                NaN     Aged 25 to 44
# 11             NaN        NaN                NaN     Aged 45 to 64
# 12             NaN        NaN  Aged 65 and over                 NaN
# ...

# %%
male_age_range=['Male a'+ temp[1:] for temp in age_range]

# %%
for col in male_age_range:
    new_df[col]=0.0

# %%
new_df.head()
# Out:
#                                 Aged 0 to 4   Aged 5 to 15   Aged 16 to 24   \
# 2010 North East                     148513.0       313212.0        320432.0
#      North West                     429023.0       891638.0        855968.0
#      Yorkshire and the Humber       325361.0       666608.0        660172.0
#      East Midlands                  267593.0       567675.0        540454.0
#      West Midlands                  351449.0       737376.0        671308.0
#
#                                 Aged 25 to 44   Aged 45 to 64   \
# 2010 North East                       658689.0        700570.0
#      North West                      1864164.0       1818435.0
#      Yorkshire and the Humber        1393182.0       1342786.0
#      East Midlands                   1181152.0       1187293.0
#      West Midlands                   1474432.0       1395467.0
#
#                                 Aged 65 to 74   Aged 75 to 84   \
# ...

# %%
temp_df=new_df.copy()

# %%
region_col=range(4,14)
age_row=np.array([6,7,9,10,11,13,14,15])+12*9
for i in range(10):
    for j in range(8):
        new_df.iloc[i,j+8]=float(male_region_age.iloc[age_row[j],region_col[i]])/float(uk_region_age.iloc[age_row[j],region_col[i]])

# %%
region_col=range(4,14)
age_row=age_row+12
for i in range(10):
    for j in range(8):
        new_df.iloc[i+10,j+8]=float(male_region_age.iloc[age_row[j],region_col[i]])/float(uk_region_age.iloc[age_row[j],region_col[i]])

# %%
region_col=range(4,14)
age_row=age_row+12
for i in range(10):
    for j in range(8):
        new_df.iloc[i+20,j+8]=float(male_region_age.iloc[age_row[j],region_col[i]])/float(uk_region_age.iloc[age_row[j],region_col[i]])

# %%
region_col=range(4,14)
age_row=age_row+12
for i in range(10):
    for j in range(8):
        new_df.iloc[i+30,j+8]=float(male_region_age.iloc[age_row[j],region_col[i]])/float(uk_region_age.iloc[age_row[j],region_col[i]])

# %%
region_col=range(4,14)
age_row=age_row+12
for i in range(10):
    for j in range(8):
        new_df.iloc[i+40,j+8]=float(male_region_age.iloc[age_row[j],region_col[i]])/float(uk_region_age.iloc[age_row[j],region_col[i]])

# %%
region_col=range(4,14)
age_row=age_row+12
for i in range(10):
    for j in range(8):
        new_df.iloc[i+50,j+8]=float(male_region_age.iloc[age_row[j],region_col[i]])/float(uk_region_age.iloc[age_row[j],region_col[i]])

# %%
region_col=range(4,14)
age_row=age_row+12
for i in range(10):
    for j in range(8):
        new_df.iloc[i+60,j+8]=float(male_region_age.iloc[age_row[j],region_col[i]])/float(uk_region_age.iloc[age_row[j],region_col[i]])

# %%
region_col=range(4,14)
age_row=age_row+12
for i in range(10):
    for j in range(8):
        new_df.iloc[i+70,j+8]=float(male_region_age.iloc[age_row[j],region_col[i]])/float(uk_region_age.iloc[age_row[j],region_col[i]])

# %%
region_col=range(4,14)
age_row=age_row+12
for i in range(10):
    for j in range(8):
        new_df.iloc[i+80,j+8]=float(male_region_age.iloc[age_row[j],region_col[i]])/float(uk_region_age.iloc[age_row[j],region_col[i]])

# %%
new_df
# Out:
#                                 Aged 0 to 4   Aged 5 to 15   Aged 16 to 24   \
# 2010 North East                     148513.0       313212.0        320432.0
#      North West                     429023.0       891638.0        855968.0
#      Yorkshire and the Humber       325361.0       666608.0        660172.0
#      East Midlands                  267593.0       567675.0        540454.0
#      West Midlands                  351449.0       737376.0        671308.0
# ...                                      ...            ...             ...
# 2018 East                           372157.0       828826.0        606654.0
#      London                         615881.0      1218914.0        933076.0
#      South East                     527245.0      1228022.0        950440.0
#      South West                     296357.0       690551.0        585372.0
#      England                       3346727.0      7401731.0       6005483.0
#
# ...

# %%
new_df
# Out:
#                                 Aged 0 to 4   Aged 5 to 15   Aged 16 to 24   \
# 2010 North East                     148513.0       313212.0        320432.0
#      North West                     429023.0       891638.0        855968.0
#      Yorkshire and the Humber       325361.0       666608.0        660172.0
#      East Midlands                  267593.0       567675.0        540454.0
#      West Midlands                  351449.0       737376.0        671308.0
# ...                                      ...            ...             ...
# 2018 East                           372157.0       828826.0        606654.0
#      London                         615881.0      1218914.0        933076.0
#      South East                     527245.0      1228022.0        950440.0
#      South West                     296357.0       690551.0        585372.0
#      England                       3346727.0      7401731.0       6005483.0
#
# ...

# %%
tax_2011=pd.read_excel('uk_data/uk_region_tax/uk_region_tax_1011.xls')
tax_2012=pd.read_excel('uk_data/uk_region_tax/uk_region_tax_1112.xls')
tax_2013=pd.read_excel('uk_data/uk_region_tax/uk_region_tax_1213.xls')
tax_2014=pd.read_excel('uk_data/uk_region_tax/uk_region_tax_1314.xlsx')
tax_2015=pd.read_excel('uk_data/uk_region_tax/uk_region_tax_1415.xlsx')
tax_2016=pd.read_excel('uk_data/uk_region_tax/uk_region_tax_1516.xlsx')
tax_2017=pd.read_excel('uk_data/uk_region_tax/uk_region_tax_1617.xlsx')
tax_2018=pd.read_excel('uk_data/uk_region_tax/uk_region_tax_1718.xlsx')

# %%
income_range=tax_2011.iloc[5][[2,6,10,14,18,22]]
income_range
# Out:
# Income and tax by county and region, 2010-11    Self-employment income
# Unnamed: 6                                           Employment income
# Unnamed: 10                                             Pension income
# Unnamed: 14                                          Investment Income
# Unnamed: 18                                               Total income
# Unnamed: 22                                                  Total tax
# Name: 5, dtype: object

# %%
temp_df=new_df.copy()

# %%
for temp in income_range:
    new_df[temp]=0.0

# %%
new_df
# Out:
#                                 Aged 0 to 4   Aged 5 to 15   Aged 16 to 24   \
# 2010 North East                     148513.0       313212.0        320432.0
#      North West                     429023.0       891638.0        855968.0
#      Yorkshire and the Humber       325361.0       666608.0        660172.0
#      East Midlands                  267593.0       567675.0        540454.0
#      West Midlands                  351449.0       737376.0        671308.0
# ...                                      ...            ...             ...
# 2018 East                           372157.0       828826.0        606654.0
#      London                         615881.0      1218914.0        933076.0
#      South East                     527245.0      1228022.0        950440.0
#      South West                     296357.0       690551.0        585372.0
#      England                       3346727.0      7401731.0       6005483.0
#
# ...

# %%
region_row=[18, 24, 33 ,41, 51 ,60, 70,73,95, 15,94,97,100]
tax_col=[3,7,11,15,19,23]
for i in range(10):
    for j in range(6):
        new_df.iloc[i+0,j+16]=tax_2011.iloc[region_row[i],tax_col[j]]

# %%
region_row=[18, 24, 33 ,41, 51 ,60, 70,73,95, 15,94,97,100]
tax_col=[3,7,11,15,19,23]
for i in range(10):
    for j in range(6):
        new_df.iloc[i+10,j+16]=tax_2011.iloc[region_row[i],tax_col[j]]

# %%
new_df
# Out:
#                                 Aged 0 to 4   Aged 5 to 15   Aged 16 to 24   \
# 2010 North East                     148513.0       313212.0        320432.0
#      North West                     429023.0       891638.0        855968.0
#      Yorkshire and the Humber       325361.0       666608.0        660172.0
#      East Midlands                  267593.0       567675.0        540454.0
#      West Midlands                  351449.0       737376.0        671308.0
# ...                                      ...            ...             ...
# 2018 East                           372157.0       828826.0        606654.0
#      London                         615881.0      1218914.0        933076.0
#      South East                     527245.0      1228022.0        950440.0
#      South West                     296357.0       690551.0        585372.0
#      England                       3346727.0      7401731.0       6005483.0
#
# ...

# %%
tax_2012.iloc[78][0]
# Out:
# 'South West '

# %%
region_row=[18, 23, 31 ,38, 47 ,55, 64,67,78, 15,86,89,92]
tax_col=[3,7,11,15,19,23]
for i in range(10):
    for j in range(6):
        new_df.iloc[i+20,j+16]=tax_2012.iloc[region_row[i],tax_col[j]]

# %%
tax_2013.iloc[55][0]
# Out:
# 'East of England'

# %%
region_row=[18, 23, 31 ,38, 47 ,55, 64,67,78, 15,86,89,92]
tax_col=[3,7,11,15,19,23]
for i in range(10):
    for j in range(6):
        new_df.iloc[i+30,j+16]=tax_2013.iloc[region_row[i],tax_col[j]]

# %%
tax_2014.iloc[86][0]
# Out:
# 'Wales'

# %%
region_row=[18, 23, 31 ,38, 47 ,55, 64,67,78, 15,86,89,92]
tax_col=[3,7,11,15,19,23]
for i in range(10):
    for j in range(6):
        new_df.iloc[i+40,j+16]=tax_2014.iloc[region_row[i],tax_col[j]]

# %%
tax_2015.iloc[67][0]
# Out:
# 'South East '

# %%
region_row=[18, 23, 31 ,38, 47 ,55, 64,67,78, 15,86,89,92]
tax_col=[3,7,11,15,19,23]
for i in range(10):
    for j in range(6):
        new_df.iloc[i+50,j+16]=tax_2015.iloc[region_row[i],tax_col[j]]

# %%
tax_2016.iloc[86][0]
# Out:
# 'Wales'

# %%
region_row=[18, 23, 31 ,38, 47 ,55, 64,67,78, 15,86,89,92]
tax_col=[3,7,11,15,19,23]
for i in range(10):
    for j in range(6):
        new_df.iloc[i+60,j+16]=tax_2016.iloc[region_row[i],tax_col[j]]

# %%
tax_2017.iloc[86][0]
# Out:
# 'Wales'

# %%
region_row=[18, 23, 31 ,38, 47 ,55, 64,67,78, 15,86,89,92]
tax_col=[3,7,11,15,19,23]
for i in range(10):
    for j in range(6):
        new_df.iloc[i+70,j+16]=tax_2017.iloc[region_row[i],tax_col[j]]

# %%
region_row=[18, 23, 31 ,38, 47 ,55, 64,67,78, 15,86,89,92]
tax_col=[3,7,11,15,19,23]
for i in range(10):
    for j in range(6):
        new_df.iloc[i+80,j+16]=tax_2017.iloc[region_row[i],tax_col[j]]

# %%
new_df
# Out:
#                                 Aged 0 to 4   Aged 5 to 15   Aged 16 to 24   \
# 2010 North East                     148513.0       313212.0        320432.0
#      North West                     429023.0       891638.0        855968.0
#      Yorkshire and the Humber       325361.0       666608.0        660172.0
#      East Midlands                  267593.0       567675.0        540454.0
#      West Midlands                  351449.0       737376.0        671308.0
# ...                                      ...            ...             ...
# 2018 East                           372157.0       828826.0        606654.0
#      London                         615881.0      1218914.0        933076.0
#      South East                     527245.0      1228022.0        950440.0
#      South West                     296357.0       690551.0        585372.0
#      England                       3346727.0      7401731.0       6005483.0
#
# ...

# %%
new_df.to_csv('uk_data/England_all_merge.csv',header=0)

# %%
region_row=[18, 23, 31 ,38, 47 ,55, 64,67,78, 15,86,89,92]
tax_col=[3,7,11,15,19,23]
for i in range(10):
    for j in range(6):
        new_df.iloc[i+80,j+16]=tax_2018.iloc[region_row[i],tax_col[j]]
