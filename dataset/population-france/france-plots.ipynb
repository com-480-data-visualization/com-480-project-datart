# %%
import os
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# the maximum year is 2015 because we did an inner join (see population-EDA)

# %%
df = pd.read_csv('france-merged.csv')
df.head(10)
# Out:
#    Unnamed: 0  Region Code     region  Year0  \
# 0           0           44  Grand Est   2017
# 1           1           44  Grand Est   2017
# 2           2           44  Grand Est   2017
# 3           3           44  Grand Est   2017
# 4           4           44  Grand Est   2017
# 5           5           44  Grand Est   2017
# 6           6           44  Grand Est   2017
# 7           7           44  Grand Est   2017
# 8           8           44  Grand Est   2017
# 9           9           44  Grand Est   2017
#
#                                              Score00 Surname00  Name00  \
# 0  27                                            ...    LE PEN  Marine
# 1  27                                            ...    LE PEN  Marine
# 2  27                                            ...    LE PEN  Marine
# 3  27                                            ...    LE PEN  Marine
# 4  27                                            ...    LE PEN  Marine
# ...

# %% [markdown]
# # Testing
